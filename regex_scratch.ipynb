# %%
sample_msg = "2024/05/20  11:18:19;;;;;;;;;;;;Auto;Air;0.000;NaN;806.233;1.7373;40.0766;55.0003;0;;;;;;;;;;;;;;;;;;;;;;;;;;21.3694;0.30151;1.6981;152.00;1015.46;21.13;3.02;7.66;;;;;;;;;;;;;OFF | OFF;10;30;150;Continuous;;;;;;;;;;;;;;"

# %%
sample_split = sample_msg.split(';')

# %%
len(sample_split)
# Out:
# 85

# %%
current = "[#20:15:40 02/16/2022#,##,# #,# #,##,##,##,##,##,##,##,##,#Auto#,#Air#,#0.015#,#NaN#,#541.552#,#1.3575#,#40.6180#,#55.0003#,#0#,##,##,##,##,##,##,##,##,##,##,##,##,##,##,##,##,##,##,##,##,##,##,##,##,##,#8.8544#,#0.00798#,#0.0547#,#100.31#,#1018.92#,#8.65#,#1.38#,#7.80#,##,##,##,##,##,##,##,##,##,##,#kwb#,##,#OFF|OFF#,#10#,#30#,#100#,#Continuous#,##,##,##,##,##,##,##,##,##,##,##,##,##,##]"

# %%
current_split = current.split(',')

# %%
len(current_split)
# Out:
# 85
